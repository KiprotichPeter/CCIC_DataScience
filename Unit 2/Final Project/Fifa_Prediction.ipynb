# %%
import pandas as pd

# %%
data = pd.read_csv("players_20.csv")
#data = data.drop(data.columns[[1,6,7,8,9]], axis = 1)
#data.info
#print(data.columns.tolist())

# %%
#data = data.drop(data.columns[[0,1,5,6,7,9,12,13,14,15,16,17,20,21,22,23,24,25,26,27,29,30,31,36,37,38,39,'gk_reflexes']], axis = 1)
data = data.drop(['player_url','dob','height_cm','weight_kg','club','value_eur','wage_eur','player_positions','preferred_foot','international_reputation','weak_foot','body_type',
'real_face','release_clause_eur','player_tags','team_position','team_jersey_number','loaned_from','joined','contract_valid_until','nation_position','nation_jersey_number','physic','gk_diving','gk_handling',
'gk_kicking','gk_reflexes','gk_speed','gk_positioning','player_traits','skill_curve','goalkeeping_diving','goalkeeping_handling','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes','ls',
'st','rs','lw','lf','cf','rf','rw','lam','cam','ram','lm','lcm','cm','rcm','rm','lwb','ldm','cdm','rdm','rwb','lb','lcb','cb','rcb','rb'], axis = 1)
data.dropna()
data
# Out:
#        sofifa_id         short_name                            long_name  age  \
# 0         158023           L. Messi       Lionel Andrés Messi Cuccittini   32
# 1          20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# 2         190871          Neymar Jr        Neymar da Silva Santos Junior   27
# 3         200389           J. Oblak                            Jan Oblak   26
# 4         183277          E. Hazard                          Eden Hazard   28
# ...          ...                ...                                  ...  ...
# 18273     245006         Shao Shuai                                   邵帅   22
# 18274     250995       Xiao Mingjie                         Mingjie Xiao   22
# 18275     252332          Zhang Wei                                   张威   19
# 18276     251110       Wang Haijian                                  汪海健   18
# 18277     233449         Pan Ximing                                  潘喜明   26
#
# ...

# %%
#Make one skil raking using all the avaibale skilled types avarage
data2 = pd.DataFrame({'skill':[]})
data = pd.concat([data, data2], axis=1)
data
#skill = data[[9:41]].average()
