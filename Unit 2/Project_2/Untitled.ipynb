# %%
import requests
import pandas as pd

# %%
#Api_Key = 87983fbe976988a9e22330ebf030a1ae

# %%
url = 'https://api.themoviedb.org/3/movie/top_rated?api_key=87983fbe976988a9e22330ebf030a1ae&page={0}'

# %%
x = requests.get(url)
x = x.json()
#print(x)

# %%
data = pd.DataFrame(x)
data
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/tmU7GeKVyb...          528
# 1      1  {'adult': False, 'backdrop_path': '/rl7Jw8PjhS...          528
# 2      1  {'adult': False, 'backdrop_path': '/kXfqcdQKsT...          528
# 3      1  {'adult': False, 'backdrop_path': '/bxSBOAD8Au...          528
# 4      1  {'adult': False, 'backdrop_path': '/kGzFbGhp99...          528
# 5      1  {'adult': False, 'backdrop_path': '/vI3aUGTuRR...          528
# 6      1  {'adult': False, 'backdrop_path': '/zb6fM1CX41...          528
# 7      1  {'adult': False, 'backdrop_path': '/aVFx1VtlOx...          528
# 8      1  {'adult': False, 'backdrop_path': '/Ab8mkHmkYA...          528
# 9      1  {'adult': False, 'backdrop_path': '/3RMLbSEXOn...          528
# 10     1  {'adult': False, 'backdrop_path': '/qqHQsStV6e...          528
# 11     1  {'adult': False, 'backdrop_path': '/mMtUybQ6hL...          528
# ...

# %%
data = data.drop(labels="pages", axis=1)
data = data.drop(labels="pages", axis=1)

# %%
#Read the json files
#pd_object = pd.read_json("responce","typ="series")
#df = pd.DataFrame(pd_object)
#display(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 #Read the json files
# ----> 2 pd_object = pd.read_json("responce")
#       3 df = pd.DataFrame(pd_object)
#       4 display(df)
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# ...
